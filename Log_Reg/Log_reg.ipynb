# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'], df['bought_insurance'], marker='+', color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=0.2)

# %%
x_test
# Out:
#     age
# 10   18
# 22   40
# 6    55
# 14   49
# 2    47
# 18   19

# %%
x_train
# Out:
#     age
# 12   27
# 1    25
# 0    22
# 11   28
# 15   55
# 20   21
# 25   54
# 24   50
# 8    62
# 26   23
# 23   45
# 5    56
# 7    60
# 16   25
# 9    61
# 17   58
# 13   29
# 4    46
# 3    52
# 19   18
# 21   26

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 1, 1, 1, 0])

# %%
model.score(x_test, y_test)
# Out:
# 0.8333333333333334

# %%
model.predict_proba(x_test)
# Out:
# array([[0.95982014, 0.04017986],
#        [0.4400428 , 0.5599572 ],
#        [0.07116256, 0.92883744],
#        [0.16276798, 0.83723202],
#        [0.20959335, 0.79040665],
#        [0.95338878, 0.04661122]])

# %%
model.predict([[100]])
# Out:
# c:\Users\ragin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
